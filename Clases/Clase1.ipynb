# %% [markdown]
# <a href="https://colab.research.google.com/github/eruiz1996/Diplomado/blob/main/Clases/Clase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = list(range(5))
pd.DataFrame(data)
# Out:
#    0
# 0  0
# 1  1
# 2  2
# 3  3
# 4  4

# %%
pd.DataFrame(data, columns = ['Num'])
# Out:
#    Num
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4

# %%
pd.DataFrame(data, columns = ['Num'], index = (list('abcde')))
# Out:
#    Num
# a    0
# b    1
# c    2
# d    3
# e    4

# %%
new_data = {
    'C1':list('hola'),
    'C2':list(range(4))
}
pd.DataFrame(new_data)
# Out:
#   C1  C2
# 0  h   0
# 1  o   1
# 2  l   2
# 3  a   3

# %%
data = pd.read_excel('/content/tote_shipment.xlsx')

# %%
data.head()
# Out:
#   asset_type  asset_id                           tag_id  Site            Zone  \
# 0       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 1       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 2       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 3       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 4       tote         2  (01)00850027865010(21)0082T0670  DC 1  dock_doors_DC1
#
#       device_id                time_est       lat       lng  Temperature_C  \
# 0  7F9A8353E973 2022-08-02 11:59:26.628  47.79158 -65.68902           23.0
# 1  EC5B0499234F 2022-08-02 12:00:22.660  47.79158 -65.68902           23.0
# 2  7F9A8353E973 2022-08-02 12:01:11.234  47.79158 -65.68902           23.0
# 3  3D8B2BDB8673 2022-08-02 13:47:58.172  47.79158 -65.68902           23.5
# 4  7F9A8353E973 2022-08-02 11:58:55.049  47.79158 -65.68902           23.0
#
#    Temperature_F
# 0           73.4
# ...

# %% [markdown]
# Para archivos propios, me conecto desde Colab a mi drive personal.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Para acceder a una carpeta en específico uso
#
# ```
# %cd /content/drive/My \Drive/Caperta
# ```
#
# Para cambiar el nombre de una columna en específico uso
#
# ```
# pd.rename(columns = {'name':new_name})
# ```

# %%
data.shape
# Out:
# (130061, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130061 entries, 0 to 130060
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   asset_type     130061 non-null  object
#  1   asset_id       130061 non-null  int64
#  2   tag_id         130061 non-null  object
#  3   Site           130061 non-null  object
#  4   Zone           130061 non-null  object
#  5   device_id      130061 non-null  object
#  6   time_est       130061 non-null  datetime64[ns]
#  7   lat            130061 non-null  float64
#  8   lng            130061 non-null  float64
#  9   Temperature_C  130061 non-null  float64
#  10  Temperature_F  130061 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(5)
# memory usage: 10.9+ MB

# %%
data.describe()
# Out:
#             asset_id            lat            lng  Temperature_C  \
# count  130061.000000  130061.000000  130061.000000  130061.000000
# mean      105.184475      47.760258     -65.668955      25.874445
# std        61.459262       0.019223       0.049597       2.795208
# min         2.000000      47.748780     -65.762200      19.000000
# 25%        58.000000      47.749230     -65.641010      24.000000
# 50%        84.000000      47.749230     -65.641010      25.000000
# 75%       167.000000      47.749388     -65.641010      27.500000
# max       205.000000      47.805010     -65.640330      44.000000
#
#        Temperature_F
# count  130061.000000
# mean       78.574000
# std         5.031375
# min        66.200000
# 25%        75.200000
# 50%        77.000000
# 75%        81.500000
# max       111.200000

# %% [markdown]
# Para tener todos los estadísticos usa el parámetro `include`

# %%
data.describe(include = 'all')
# Out:
# <ipython-input-14-2258166cf291>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   data.describe(include = 'all')
#        asset_type       asset_id                           tag_id    Site  \
# count      130061  130061.000000                           130061  130061
# unique          1            NaN                               34       4
# top          tote            NaN  (01)00850027865010(21)0082T0953   Store
# freq       130061            NaN                             6602   96897
# first         NaN            NaN                              NaN     NaN
# last          NaN            NaN                              NaN     NaN
# mean          NaN     105.184475                              NaN     NaN
# ...

# %%
data['Zone'].unique()
# Out:
# array(['dock_doors_DC1', 'dock_doors_DC2', 'Forklift3_DC1',
#        'pallet_assembly_DC1', 'PhoneKit1Bridge', 'PhoneKit2Bridge',
#        'PhoneKit2GW', 'point_of_sale_Store', 'receiving_Store',
#        'staging_DC1', 'staging_DC2', 'store_back_Store',
#        'store_front_Store', 'Forklift1_DC1', 'PhoneKit1GW'], dtype=object)

# %%
# contar cuántos registros únicos tengo
data['asset_id'].nunique()
# Out:
# 18

# %%
data.groupby('asset_id')['tag_id'].nunique()
# Out:
# asset_id
# 2      2
# 37     2
# 52     2
# 58     2
# 59     2
# 62     2
# 70     1
# 84     2
# 102    2
# 145    2
# 149    2
# 159    2
# 167    2
# 170    2
# 181    1
# 182    2
# 200    2
# 205    2
# Name: tag_id, dtype: int64

# %%
pd.DataFrame(data.groupby('asset_id')['tag_id'].nunique())
# Out:
#           tag_id
# asset_id
# 2              2
# 37             2
# 52             2
# 58             2
# 59             2
# 62             2
# 70             1
# 84             2
# 102            2
# 145            2
# 149            2
# 159            2
# 167            2
# 170            2
# 181            1
# 182            2
# 200            2
# 205            2

# %%
# para restaurar el índice
pd.DataFrame(data.groupby('asset_id')['tag_id'].nunique()).reset_index()
# Out:
#     asset_id  tag_id
# 0          2       2
# 1         37       2
# 2         52       2
# 3         58       2
# 4         59       2
# 5         62       2
# 6         70       1
# 7         84       2
# 8        102       2
# 9        145       2
# 10       149       2
# 11       159       2
# 12       167       2
# 13       170       2
# 14       181       1
# 15       182       2
# 16       200       2
# 17       205       2

# %% [markdown]
# Cambiar valores vacíos
#
#
# ```
# df.fillna(valor)
# ```
